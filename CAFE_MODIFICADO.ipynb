# %% [markdown]
# <a href="https://colab.research.google.com/github/Leal-Flores-Rodrigo/ESTRUCTURA-Y-ORGANIZACION-DE-DATOS/blob/main/CAFE_MODIFICADO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
COMIDA=[]
BEBIDA=[]
ALUMNO=[]

def comida():

    com=["PAN","TORTA","SANDWUIC","QUESADILLAS","TACOS"]
    for i in com:
        COMIDA.append(i)
    return COMIDA

def Bebida():
    print("  BEBIDAS  ")

    for i in range (1,6):
        beb=input(f"ingresa la bebida {i}  ")
        BEBIDA.extend(beb)
    return BEBIDA

def llenar():

    while True:
        alumno=input("dame el nombre del alumno  ")
        ALUMNO.append(alumno)
        resp=input("¿Desea agregar otro alumno? (s/n): ")
        if resp=="s" or resp =="S":
            continue
        else:
            break
    return ALUMNO


def asignar():

    for alumnos,comidas ,bebidas in zip(ALUMNO,COMIDA,BEBIDA):
        print(" {0} : ALMORZO:{1},Y DE TOMO  :{2}".format(alumnos,comidas,bebidas))

    for i in range (len(ALUMNO)):
        ALUMNO.pop()

def contar_platillos ():

    print("HAY ",len(COMIDA), "PLATILLOS ")

def agregar ():
  COMIDA[2]=" gorditas"
  print(COMIDA)



def menu():
        comida()


        while True:
            print("\n Ingrese la opcion")
            print("1.Agregar alumno")
            print("2.Asignar_comida")
            print("3.Agregar bebidas ")
            print("4.contar platilos ")
            print("5.Agregar comida ")

            print("6.salir")

            opcion = int(input("Opción: "))
            if opcion==1:

                llenar()
            elif opcion==2:
                asignar()
            elif opcion==3:

                Bebida()
            elif opcion==4:
              contar_platillos()
            elif opcion==5:
              agregar()


            else:
                break
            resp=input("¿Desea hacer otra opcion ? (s/n): ")
            if resp=="s":
                continue
            else:
                break
print(" ! GRACIAS !  ")



menu()
