# %% [markdown]
# <a href="https://colab.research.google.com/github/Leal-Flores-Rodrigo/ESTRUCTURA-Y-ORGANIZACION-DE-DATOS/blob/main/adivina_el_numero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
class juego:

  def __init__(self,num):
    self.num=num
    self.jug=[]



  def nombre_jug(self):
    nombre=input("\nDame tu nombre ")
    self.jug.append(nombre)


  def crear_num(self):
    self.num = random.randint(1, 1000)
    #print(self.num)
    return self.num


  def jugar (self,intento=1):
    print(f"\nintento {intento}")
    respuesta=int(input(" Dame tu numero  ---> "))

    if respuesta < self.num:
      print("El numero que buscas  es mayor")
    elif respuesta > self.num:
      print("El numero que buscas  es menor")
    else:
      print("es igual es numero")
      self.jug.append(intento)
      self.jug.append("Ganó")

    if respuesta !=self.num:
      if respuesta != self.num:
        if intento < 10:
          print("fallaste intentalo denuevo ")
          intento += 1
          obj1.jugar(intento)
        else:
          print("perdiste numero no encontrado ")
          self.jug.append(intento)
          self.jug.append("Perdió")

      else:
          print("perdiste ")
    else:
      print("Ganaste")
      print(f"ganaste en  {intento} intentos")



obj1=juego(0)
while True:
  obj1.nombre_jug()
  obj1.crear_num()
  obj1.jugar()
  print("\n")
  print(obj1.jug)
  resp=input("\n desea jugar denuevo  (s/n)")
  if resp =="s":
    continue
  else :
    break
# Out:
# Dame tu nombre juan
#
# intento 1
#  Dame tu numero  ---> 45
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 2
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 3
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 4
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 5
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 6
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 7
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 8
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 9
#  Dame tu numero  ---> 4
# El numero que buscas  es mayor
# fallaste intentalo denuevo
#
# intento 10
#  Dame tu numero  ---> 4
# ...
